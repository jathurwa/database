# %% [markdown]
# <a href="https://colab.research.google.com/github/jathurwa/database/blob/main/HIV/AIDs%20Demographic%20for%20CEMA%20Data%20Science%20Application.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-09ff5213-ba70-4548-ac52-19cb30872260" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-09ff5213-ba70-4548-ac52-19cb30872260">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dataframe = pd.read_csv("HIV data 2000-2023.csv", encoding='latin1',low_memory=False)

# %%
dataframe.head(15)
# Out:
#      IndicatorCode                                          Indicator  \
# 0   HIV_0000000001  Estimated number of people (all ages) living w...
# 1   HIV_0000000001  Estimated number of people (all ages) living w...
# 2   HIV_0000000001  Estimated number of people (all ages) living w...
# 3   HIV_0000000001  Estimated number of people (all ages) living w...
# 4   HIV_0000000001  Estimated number of people (all ages) living w...
# 5   HIV_0000000001  Estimated number of people (all ages) living w...
# 6   HIV_0000000001  Estimated number of people (all ages) living w...
# 7   HIV_0000000001  Estimated number of people (all ages) living w...
# 8   HIV_0000000001  Estimated number of people (all ages) living w...
# 9   HIV_0000000001  Estimated number of people (all ages) living w...
# 10  HIV_0000000001  Estimated number of people (all ages) living w...
# 11  HIV_0000000001  Estimated number of people (all ages) living w...
# ...

# %%
dataframe.isnull().sum()
# Out:
# IndicatorCode          0
# Indicator              0
# ValueType              0
# ParentLocationCode     0
# ParentLocation         0
# Location type          0
# SpatialDimValueCode    0
# Location               0
# Period type            0
# Period                 0
# Value                  0
# dtype: int64

# %%
dataframe.isnull()
# Out:
#       IndicatorCode  Indicator  ValueType  ParentLocationCode  ParentLocation  \
# 0             False      False      False               False           False
# 1             False      False      False               False           False
# 2             False      False      False               False           False
# 3             False      False      False               False           False
# 4             False      False      False               False           False
# ...             ...        ...        ...                 ...             ...
# 1547          False      False      False               False           False
# 1548          False      False      False               False           False
# 1549          False      False      False               False           False
# 1550          False      False      False               False           False
# 1551          False      False      False               False           False
#
# ...

# %% [markdown]
# Since the **dataset is clean** we can proceed with the *analysis*

# %% [markdown]
# Before that lets check the data type of the columns

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1552 entries, 0 to 1551
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   IndicatorCode        1552 non-null   object
#  1   Indicator            1552 non-null   object
#  2   ValueType            1552 non-null   object
#  3   ParentLocationCode   1552 non-null   object
#  4   ParentLocation       1552 non-null   object
#  5   Location type        1552 non-null   object
#  6   SpatialDimValueCode  1552 non-null   object
#  7   Location             1552 non-null   object
#  8   Period type          1552 non-null   object
#  9   Period               1552 non-null   int64
#  10  Value                1552 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 133.5+ KB

# %% [markdown]
# Since the value column is also an OBJECT first we must change it to intergers

# %%
# prompt: i need a code that will change the value column datatype from object to integer

import pandas as pd
# Convert the 'value' column to numeric, coercing errors to NaN
dataframe['value'] = pd.to_numeric(dataframe['value'], errors='coerce')

# Now, convert the NaN values in the 'value' column to 0
dataframe['value'] = dataframe['value'].fillna(0).astype(int)

# Verify the changes
print(dataframe.info())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'value'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-9a3e5ce7a3f2> in <cell line: 0>()
#       3 import pandas as pd
# ...

# %%
dataframe['Numericvalue'] = dataframe['Value'].str.extract(r'(\d+)').astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-df75bc46788e> in <cell line: 0>()
# ----> 1 dataframe['Numericvalue'] = dataframe['Value'].str.extract(r'(\d+)').astype(int)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
#     432             dtype=dtype,
#
# ...

# %%
import pandas as pd

# Convert the 'Value' column to numeric, coercing errors to NaN
dataframe['Numericvalue(000)'] = pd.to_numeric(dataframe['Value'].str.extract(r'(\d+)')[0], errors='coerce')

# Now, convert the NaN values in the 'Numericvalue' column to 0 and change the type to int
dataframe['Numericvalue(000)'] = dataframe['Numericvalue(000)'].fillna(0).astype(int)

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1552 entries, 0 to 1551
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   IndicatorCode        1552 non-null   object
#  1   Indicator            1552 non-null   object
#  2   ValueType            1552 non-null   object
#  3   ParentLocationCode   1552 non-null   object
#  4   ParentLocation       1552 non-null   object
#  5   Location type        1552 non-null   object
#  6   SpatialDimValueCode  1552 non-null   object
#  7   Location             1552 non-null   object
#  8   Period type          1552 non-null   object
#  9   Period               1552 non-null   int64
#  10  Value                1552 non-null   object
#  11  Numericvalue(000)    1552 non-null   int64
# dtypes: int64(2), object(10)
# memory usage: 145.6+ KB

# %%
dataframe = dataframe.drop(['Value'], axis=1)

# %%
dataframe = dataframe.rename(columns={'Numericvalue(000)': 'Value(000)'})#changing column name to original name that had being removed

# %%
dataframe.head(15)
# Out:
#      IndicatorCode                                          Indicator  \
# 0   HIV_0000000001  Estimated number of people (all ages) living w...
# 1   HIV_0000000001  Estimated number of people (all ages) living w...
# 2   HIV_0000000001  Estimated number of people (all ages) living w...
# 3   HIV_0000000001  Estimated number of people (all ages) living w...
# 4   HIV_0000000001  Estimated number of people (all ages) living w...
# 5   HIV_0000000001  Estimated number of people (all ages) living w...
# 6   HIV_0000000001  Estimated number of people (all ages) living w...
# 7   HIV_0000000001  Estimated number of people (all ages) living w...
# 8   HIV_0000000001  Estimated number of people (all ages) living w...
# 9   HIV_0000000001  Estimated number of people (all ages) living w...
# 10  HIV_0000000001  Estimated number of people (all ages) living w...
# 11  HIV_0000000001  Estimated number of people (all ages) living w...
# ...

# %%
# prompt: that downloads the excel file with the above modifications

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files

# Upload the file
uploaded = files.upload()

# Get the filename from the uploaded files
for filename in uploaded.keys():
    print(f'User uploaded file "{filename}"')
    csv_filename = filename  # Assuming only one file is uploaded

# Read the CSV file, handling encoding and potential errors
try:
    dataframe = pd.read_csv(csv_filename, encoding='latin1', low_memory=False)
    print("File read successfully.")
except FileNotFoundError:
    print(f"Error: File '{csv_filename}' not found.")
except pd.errors.ParserError:
    print(f"Error: Could not parse the file '{csv_filename}'. Check its format.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
else:
    # ... (rest of your code)
    dataframe.head(15)
    dataframe.isnull().sum()
    dataframe.isnull()

    dataframe.info()

    # Convert the 'value' column to numeric, coercing errors to NaN


    # Convert the 'Value' column to numeric, coercing errors to NaN
    dataframe['Numericvalue(000)'] = pd.to_numeric(dataframe['Value'].str.extract(r'(\d+)')[0], errors='coerce')

    # Now, convert the NaN values in the 'Numericvalue' column to 0 and change the type to int
    dataframe['Numericvalue(000)'] = dataframe['Numericvalue(000)'].fillna(0).astype(int)
    print(dataframe.info())

    # Extract numeric values from the 'Value' column
    if 'Value' in dataframe.columns:
        dataframe['Numericvalue'] = dataframe['Value'].str.extract(r'(\d+)').astype(float) # changed to float type
        dataframe['Numericvalue'] = dataframe['Numericvalue'].fillna(0).astype(int) # fillna and change to int

        dataframe = dataframe.drop(['Value'], axis=1)
        dataframe = dataframe.rename(columns={'Numericvalue': 'Value(000)'}) #renaming column

        dataframe.head(15)

        # Save the modified DataFrame to a new Excel file
        excel_filename = 'modified_HIV_data.xlsx'
        dataframe.to_excel(excel_filename, index=False)  # index=False prevents writing row indices to the file
        files.download(excel_filename)

    else:
      print("The 'Value' column is not found in the dataframe. Please check your input file.")
# Out:
#      <input type="file" id="files-33615bf1-15b9-442c-bdb4-f65452bfd32d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-33615bf1-15b9-442c-bdb4-f65452bfd32d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#calculating number of HIV cases for each country over the whole period

HIV_Total_cases = dataframe.groupby('Location')['Value(000)'].sum()
print (HIV_Total_cases)
# Out:
# Location
# Afghanistan                           15046
# Albania                                8210
# Algeria                                8218
# Andorra                                   0
# Angola                                 2160
#                                       ...
# Venezuela (Bolivarian Republic of)      724
# Viet Nam                               1750
# Yemen                                 22156
# Zambia                                 2495
# Zimbabwe                                  8
# Name: Value(000), Length: 194, dtype: int64

# %%
#Sorting the total case per country in ascending order
HIV_Total_cases = HIV_Total_cases.sort_values(ascending=False)
print (HIV_Total_cases)
# Out:
# Location
# Mauritania                                              59700
# Saudi Arabia                                            58211
# Israel                                                  57900
# Estonia                                                 47500
# Suriname                                                47400
#                                                         ...
# Tuvalu                                                      0
# United States of America                                    0
# United Kingdom of Great Britain and Northern Ireland        0
# Trkiye                                                     0
# Vanuatu                                                     0
# Name: Value(000), Length: 194, dtype: int64

# %%
Overall_total_cases = HIV_Total_cases.sum()
print (Overall_total_cases)
# Out:
# 1577027

# %%
cumulative_percentage_per_country = HIV_Total_cases.cumsum() / HIV_Total_cases.sum() * 100
print(cumulative_percentage_per_country)
# Out:
# Location
# Mauritania                                                3.785604
# Saudi Arabia                                              7.476790
# Israel                                                   11.148256
# Estonia                                                  14.160252
# Suriname                                                 17.165908
#                                                            ...
# Tuvalu                                                  100.000000
# United States of America                                100.000000
# United Kingdom of Great Britain and Northern Ireland    100.000000
# Trkiye                                                 100.000000
# Vanuatu                                                 100.000000
# Name: Value(000), Length: 194, dtype: float64

# %%
countries_75_percent = cumulative_percentage_per_country[cumulative_percentage_per_country <= 75].index
print(countries_75_percent)
# Out:
# Index(['Mauritania', 'Saudi Arabia', 'Israel', 'Estonia', 'Suriname',
#        'Azerbaijan', 'Ireland', 'Denmark', 'Singapore', 'Latvia', 'Tunisia',
#        'Guyana', 'Georgia', 'Libya', 'Somalia', 'Bahamas', 'Sri Lanka',
#        'Nicaragua', 'Djibouti', 'Armenia', 'Belize', 'Cabo Verde', 'Czechia',
#        'New Zealand', 'Kyrgyzstan', 'Yemen', 'Serbia', 'Lithuania', 'Bulgaria',
#        'Mauritius', 'Uruguay', 'Costa Rica', 'Greece',
#        'Lao People's Democratic Republic', 'Oman'],
#       dtype='object', name='Location')

# %%
#filter countries
data_75_percent = dataframe[dataframe['Location'].isin(countries_75_percent)]
print(data_75_percent)
# Out:
#        IndicatorCode                                          Indicator  \
# 88    HIV_0000000001  Estimated number of people (all ages) living w...
# 89    HIV_0000000001  Estimated number of people (all ages) living w...
# 90    HIV_0000000001  Estimated number of people (all ages) living w...
# 91    HIV_0000000001  Estimated number of people (all ages) living w...
# 92    HIV_0000000001  Estimated number of people (all ages) living w...
# ...              ...                                                ...
# 1499  HIV_0000000001  Estimated number of people (all ages) living w...
# 1500  HIV_0000000001  Estimated number of people (all ages) living w...
# 1501  HIV_0000000001  Estimated number of people (all ages) living w...
# 1502  HIV_0000000001  Estimated number of people (all ages) living w...
# 1503  HIV_0000000001  Estimated number of people (all ages) living w...
#
#      ValueType ParentLocationCode   ParentLocation Location type  \
# ...

# %%
print(data_75_percent.head(15))
# Out:
#       IndicatorCode                                          Indicator  \
# 88   HIV_0000000001  Estimated number of people (all ages) living w...
# 89   HIV_0000000001  Estimated number of people (all ages) living w...
# 90   HIV_0000000001  Estimated number of people (all ages) living w...
# 91   HIV_0000000001  Estimated number of people (all ages) living w...
# 92   HIV_0000000001  Estimated number of people (all ages) living w...
# 93   HIV_0000000001  Estimated number of people (all ages) living w...
# 94   HIV_0000000001  Estimated number of people (all ages) living w...
# 95   HIV_0000000001  Estimated number of people (all ages) living w...
# 216  HIV_0000000001  Estimated number of people (all ages) living w...
# 217  HIV_0000000001  Estimated number of people (all ages) living w...
# 218  HIV_0000000001  Estimated number of people (all ages) living w...
# 219  HIV_0000000001  Estimated number of people (all ages) living w...
# ...

# %%
print(data_75_percent.shape)
# Out:
# (280, 12)

# %% [markdown]
# # B![types-of-data-visualization-charts-main.jpg](data:image/jpeg;base64,...)eginning of ***Visualization*** **bold text**

# %%
sns.set(style = "whitegrid")

# %%
#ploting of the trends of HIV cases in the countries contributing 75% global case
plt.figure(figsize=(14,8))

sns.lineplot(dataframe=data_75_percent, x ='Period', y="Numericvalue(000)", hue='Location', palette='tab01')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-c0d6d53b4761> in <cell line: 0>()
#       2 plt.figure(figsize=(14,8))
#       3
# ----> 4 sns.lineplot(dataframe=data_75_percent, x ='Period', y="Numericvalue(000)", hue='Location', palette='tab01')
#
# /usr/local/lib/python3.11/dist-packages/seaborn/relational.py in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     483     errorbar = _deprecate_ci(errorbar, ci)
#     484
# --> 485     p = _LinePlotter(
#     486         data=data,
#     487         variables=dict(
#
# ...

# %%
#reading column Period
data_75_percent['Period']
print(data_75_percent['Period'])
# Out:
# 88      2023
# 89      2022
# 90      2021
# 91      2020
# 92      2015
#         ...
# 1499    2020
# 1500    2015
# 1501    2010
# 1502    2005
# 1503    2000
# Name: Period, Length: 280, dtype: int64

# %%
pip install seaborn

# %%
pip uninstall seaborn
# Out:
# Found existing installation: seaborn 0.13.2
# Uninstalling seaborn-0.13.2:
#   Would remove:
#     /usr/local/lib/python3.11/dist-packages/seaborn-0.13.2.dist-info/*
#     /usr/local/lib/python3.11/dist-packages/seaborn/*
# Proceed (Y/n)? Y
#   Successfully uninstalled seaborn-0.13.2

# %%
pip install seaborn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 5.6 MB/s eta 0:00:00
# ...

# %%
import seaborn as sns
sns.set(style = "whitegrid")

# %%
sns.set(style = "whitegrid")
plt.figure(figsize=(20,10))
plt.title("HIV Trends for 75% Contributors")
plt.xlabel("YEARs")
plt.ylabel("No. of People Living With HIV")

# Add legend outside the plot
plt.legend(title='Country', bbox_to_anchor=(1.05, 1), loc='upper left')

sns.lineplot(data=data_75_percent, x ='Period', y="Numericvalue(000)", hue='Location', palette='tab10')
# Out:
# <ipython-input-56-2338edbff9d6>:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title='Country', bbox_to_anchor=(1.05, 1), loc='upper left')
# <Axes: title={'center': 'HIV Trends for 75% Contributors'}, xlabel='YEARs', ylabel='No. of People Living With HIV'>
